# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
resnet50_baseline_loss =     [1.3777, 0.8046, 0.8515, 0.7762, 0.7475, 0.7381, 0.7230, 0.7347, 0.6601, 0.6632, 0.7346, 0.8855, 0.5895, 0.6225, 0.7027, 0.6783, 0.6148, 0.7505, 0.6258, 0.8924]
resnet50_baseline_accuracy = [0.6632, 0.7358, 0.7409, 0.7254, 0.7150, 0.6891, 0.7202, 0.7202, 0.7306, 0.7409, 0.6995, 0.6995, 0.7565, 0.7565, 0.7150, 0.7409, 0.7565, 0.7358, 0.7409, 0.7047]

alexnet_baseline_loss =     [1.0512, 0.7107, 0.8213, 0.6313, 0.5521, 0.6139, 0.8123, 0.5689, 0.6236, 0.6366, 0.5513, 0.6271, 0.5060, 0.7074, 0.6485, 0.5861, 0.5743, 0.7381, 0.7270, 0.5649]
alexnet_baseline_accuracy = [0.7409, 0.7202, 0.7461, 0.7565, 0.7772, 0.7098, 0.7306, 0.7668, 0.7876, 0.7668, 0.7617, 0.7202, 0.7772, 0.6995, 0.7358, 0.7617, 0.7720, 0.7927, 0.7409, 0.7720]

vgg16_baseline_loss =     [0.8954, 0.8889, 0.7974, 0.8077, 0.8128, 0.6981, 0.6843, 0.7140, 0.6481, 0.6314, 0.6278, 0.6002, 0.5831, 0.6950, 0.4810, 0.6034, 0.5373, 0.5847, 0.4763, 0.7009]
vgg16_baseline_accuracy = [0.6943, 0.7202, 0.7617, 0.7617, 0.6995, 0.7047, 0.7513, 0.7202, 0.7461, 0.7306, 0.7617, 0.7254, 0.8083, 0.6995, 0.7876, 0.7772, 0.7720, 0.7409, 0.7979, 0.7617]

# %%
x = np.arange(1, 6)
plt.plot(x, resnet50_baseline_loss, marker = 'o', color = 'b', markersize = 10)
plt.plot(x, alex400_loss, marker = 'x', color = 'b', markersize = 10)
plt.plot(x, vgg400_loss, marker = '+', color = 'b', markersize = 10)
plt.legend(['Resnet50', 'AlexNet', 'VGG16'])
plt.xticks(x)
plt.title('Loss by Iteration for n = 10015 data points')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.show()

# %%
resnet400_loss = [1.4018, 2.7033, 1.5795, 1.1794, 1.2329]
resnet400_acc = [.6373, .6321, .5907, .6373, .5337]

resnet2000_loss = [1.3522, .9895, 1.1362, 1.0405, .9573]
resnet2000_acc = [.6010, .6580, .6425, .6891, .6632]

resnet5000_loss = [.9979, 1.4421, .8625, .8857, .7996]
resnet5000_acc = [.6580, .6528, .6684, .6839, .7150]

# %%
alex400_loss = [1.3079, 1.2412, 1.2246, 1.0769, 1.2048]
alex400_acc = [.6373, .5907, .6010, .6010, .6580]

alex2000_loss = [1.3248, 1.1973, 0.9258, 1.1020, .9364]
alex2000_acc = [.6166, .6839, .7047, .6269, .6891]

alex5000_loss = [.9566, .8823, .8177, .7628, .8204]
alex5000_acc = [.6995, .7150, .7098, .6891, .6995]

# %%
vgg400_loss = [1.6486, 1.1453, 1.3805, 1.3499, 1.1751]
vgg400_acc = [.6373, .6114, .6010, .6062, .6632]

vgg2000_loss = [1.3240, 1.0839, 1.2013, 1.1288, .9779]
vgg2000_acc = [.4819, .6528, .6995, .6788, .6995]

vgg5000_loss = [1.0422, .9636, .9715, .8610, .8687]
vgg5000_acc = [.7047, .6632, .6995, .7254, .7461]

# %%
x = np.arange(1, 6)
plt.plot(x, resnet400_loss, marker = 'o', color = 'b', markersize = 10)
plt.plot(x, alex400_loss, marker = 'x', color = 'b', markersize = 10)
plt.plot(x, vgg400_loss, marker = '+', color = 'b', markersize = 10)
plt.legend(['Resnet50', 'AlexNet', 'VGG16'])
plt.xticks(x)
plt.title('Loss by Epoch for n = 400 data points')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
x = np.arange(1, 6)
plt.plot(x, resnet2000_loss, marker = 'o', color = 'b', markersize = 10)
plt.plot(x, alex2000_loss, marker = 'x', color = 'b', markersize = 10)
plt.plot(x, vgg2000_loss, marker = '+', color = 'b', markersize = 10)
plt.legend(['Resnet50', 'AlexNet', 'VGG16'])
plt.xticks(x)
plt.title('Loss by Epoch for n = 2000 data points')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
x = np.arange(1, 6)
plt.plot(x, resnet5000_loss, marker = 'o', color = 'b', markersize = 10)
plt.plot(x, alex5000_loss, marker = 'x', color = 'b', markersize = 10)
plt.plot(x, vgg5000_loss, marker = '+', color = 'b', markersize = 10)
plt.legend(['Resnet50', 'AlexNet', 'VGG16'])
plt.xticks(x)
plt.title('Loss by Epoch for n = 5000 data points')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
x = np.arange(1, 6)
plt.plot(x, resnet5000_acc, marker = 'o', color = 'b', markersize = 10)
plt.plot(x, alex5000_acc, marker = 'x', color = 'b', markersize = 10)
plt.plot(x, vgg5000_acc, marker = '+', color = 'b', markersize = 10)
plt.legend(['Resnet50', 'AlexNet', 'VGG16'])
plt.xticks(x)
plt.title('Accuracy by Epoch for n = 5000 data points')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

# %%
x = np.arange(1, 6)
plt.plot(x, resnet2000_acc, marker = 'o', color = 'b', markersize = 10)
plt.plot(x, alex2000_acc, marker = 'x', color = 'b', markersize = 10)
plt.plot(x, vgg2000_acc, marker = '+', color = 'b', markersize = 10)
plt.legend(['Resnet50', 'AlexNet', 'VGG16'])
plt.xticks(x)
plt.title('Accuracy by Epoch for n = 2000 data points')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

# %%
x = np.arange(1, 6)
plt.plot(x, resnet400_acc, marker = 'o', color = 'b', markersize = 10)
plt.plot(x, alex400_acc, marker = 'x', color = 'b', markersize = 10)
plt.plot(x, vgg400_acc, marker = '+', color = 'b', markersize = 10)
plt.legend(['Resnet50', 'AlexNet', 'VGG16'])
plt.xticks(x)
plt.title('Accuracy by Epoch for n = 400 data points')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

# %%
label_directory = {'MEL': 23, 'NV': 34, 'BCC': 11, 'AKIEC': 5, 'BKL': 27, 'DF': 0, 'VASC': 0}

# %%
plt.bar(label_directory.keys(), label_directory.values())
plt.title('Total errors by skin lesion classification')
# Out:
# Text(0.5, 1.0, 'Total errors by skin lesion classification')

# %%
resnet_linear_loss = [.7073, .5824, .5935, .5856, .6664]
resnet_linear_acc = [.7565, .7979, .7927, .7979, .7720]

vgg_linear_loss = [1.1109, 1.1856, .9437, 1.0940, .8711]
vgg_linear_acc = [.6891, .6580, .6632, .7098, .6943]

alex_linear_loss = [1.4442, 1.6479, 2.2089, 1.1424, .9629]
alex_linear_acc = [.6632, .6736, .6839, .6995, .8031]

# %%
resnet_finetune_loss = [.4656, 1.0347, .4418, .5869, 1.5301]
resnet_finetune_acc = [.8342, .8446, .8756, .8394, .8497]

alex_finetune_loss = [.6725, .4936, .4992, .4658, .4570]
alex_finetune_acc = [.7772, .8135, .8238, .8290, .8653]

vgg_finetune_loss = [.7101, .600, .5593, .6708, .5383]
vgg_finetune_acc = [.7772, .7565, .8135, .7720, .8238]

# %%
x = np.arange(1, 6)
plt.plot(x, resnet_linear_loss, marker = 'o', color = 'b', markersize = 10)
plt.plot(x, alex_linear_loss, marker = 'x', color = 'b', markersize = 10)
plt.plot(x, vgg_linear_loss, marker = '+', color = 'b', markersize = 10)
plt.legend(['Resnet50', 'AlexNet', 'VGG16'])
plt.xticks(x)
plt.title('Loss by Epoch for linear models')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
x = np.arange(1, 6)
plt.plot(x, resnet_linear_acc, marker = 'o', color = 'b', markersize = 10)
plt.plot(x, alex_linear_acc, marker = 'x', color = 'b', markersize = 10)
plt.plot(x, vgg_linear_acc, marker = '+', color = 'b', markersize = 10)
plt.legend(['Resnet50', 'AlexNet', 'VGG16'])
plt.xticks(x)
plt.title('Accuracy by Epoch for linear models')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

# %%
x = np.arange(1, 6)
plt.plot(x, resnet_finetune_loss, marker = 'o', color = 'b', markersize = 10)
plt.plot(x, alex_finetune_loss, marker = 'x', color = 'b', markersize = 10)
plt.plot(x, vgg_finetune_loss, marker = '+', color = 'b', markersize = 10)
plt.legend(['Resnet50', 'AlexNet', 'VGG16'])
plt.xticks(x)
plt.title('Loss by Epoch for finetuned models')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
x = np.arange(1, 6)
plt.plot(x, resnet_finetune_acc, marker = 'o', color = 'b', markersize = 10)
plt.plot(x, alex_finetune_acc, marker = 'x', color = 'b', markersize = 10)
plt.plot(x, vgg_finetune_acc, marker = '+', color = 'b', markersize = 10)
plt.legend(['Resnet50', 'AlexNet', 'VGG16'])
plt.xticks(x)
plt.title('Accuracy by Epoch for finetuned models')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()
